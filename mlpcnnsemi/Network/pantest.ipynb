# %%
import pandas as pd
import csv
import numpy as np

# %%
path = "C:/Users/asus/Desktop/API/dataset/Dataset.csv"

# %%
p = pd.read_csv(path)

# %%
p
# Out:
#       Class  aptamer_frequency_A  aptamer_frequency_C  aptamer_frequency_G  \
# 0         1                0.386                0.229                0.257
# 1         1                0.308                0.269                0.423
# 2         1                0.321                0.250                0.321
# 3         1                0.207                0.034                0.448
# 4         1                0.182                0.364                0.212
# ...     ...                  ...                  ...                  ...
# 3399      0                0.097                0.129                0.484
# 3400      0                0.313                0.188                0.094
# 3401      0                0.233                0.311                0.222
# 3402      0                0.283                0.208                0.189
# 3403      0                0.309                0.206                0.235
#
# ...

# %%
a = np.array(p)

# %%
a[0][1:]
# Out:
# array([ 3.86000000e-01,  2.29000000e-01,  2.57000000e-01,  1.29000000e-01,
#         1.30000000e-01,  1.16000000e-01,  1.01000000e-01,  4.30000000e-02,
#         1.16000000e-01,  0.00000000e+00,  4.30000000e-02,  5.80000000e-02,
#         8.70000000e-02,  7.20000000e-02,  8.70000000e-02,  1.40000000e-02,
#         5.80000000e-02,  4.30000000e-02,  1.40000000e-02,  1.40000000e-02,
#         4.40000000e-02,  4.40000000e-02,  2.90000000e-02,  1.50000000e-02,
#         7.40000000e-02,  0.00000000e+00,  2.90000000e-02,  1.50000000e-02,
#         2.90000000e-02,  1.50000000e-02,  5.90000000e-02,  0.00000000e+00,
#         2.90000000e-02,  0.00000000e+00,  1.50000000e-02,  0.00000000e+00,
#         4.40000000e-02,  2.90000000e-02,  2.90000000e-02,  1.50000000e-02,
#         0.00000000e+00,  0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#         2.90000000e-02,  1.50000000e-02,  0.00000000e+00,  0.00000000e+00,
# ...
